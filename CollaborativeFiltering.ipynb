# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Đọc dữ liệu và tiền xử lý

# %%
# Import library
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define column names based on the provided information
column_names = ["item_id", "Title", "Release Date", "Video Release Date", "IMDb URL",
                "Unknown", "Action", "Adventure", "Animation", "Children's",
                "Comedy", "Crime", "Documentary", "Drama", "Fantasy",
                "Film-Noir", "Horror", "Musical", "Mystery", "Romance",
                "Sci-Fi", "Thriller", "War", "Western"]

# Read the file with '|' delimiter and specifying column names
item_df = pd.read_csv("/content/drive/MyDrive/Recommendation-System/data/ml-100k/u.item", sep='|', names=column_names, encoding='latin-1')


# Define column names based on the provided information
column_names = ["User ID", "Age", "Gender", "Occupation", "ZIP Code"]

# Read the file with '|' delimiter and specifying column names
user_df = pd.read_csv("/content/drive/MyDrive/Recommendation-System/data/ml-100k/u.user", sep='|', names=column_names, encoding='latin-1')


# Đọc dữ liệu từ file "ua.base" vào DataFrame
ratings_df = pd.read_csv("/content/drive/MyDrive/Recommendation-System/data/ml-100k/ua.base", sep='\t', header=None)

# Đặt tên cho các cột
ratings_df.columns = ['user_id', 'item_id', 'rating', 'timestamp']

# %%
ratings_df.drop('timestamp', axis=1, inplace=True)

# %% [markdown]
# # Tổ chức CF

# %%
class CF(object):
    """docstring for CF"""
    def __init__(self, Y_data, k, dist_func = cosine_similarity, uuCF = 1):
        self.uuCF = uuCF # user-user (1) or item-item (0) CF
        self.Y_data = Y_data if uuCF else Y_data[:, [1, 0, 2]]
        self.k = k
        self.dist_func = dist_func
        self.Ybar_data = None
        # number of users and items. Remember to add 1 since id starts from 0
        self.n_users = int(np.max(self.Y_data[:, 0])) + 1
        self.n_items = int(np.max(self.Y_data[:, 1])) + 1
        self.predict = None

    def add(self, new_data):
        """
        Update Y_data matrix when new ratings come.
        For simplicity, suppose that there is no new user or item.
        """
        self.Y_data = np.concatenate((self.Y_data, new_data), axis = 0)

    def normalize_Y(self):
        users = self.Y_data[:, 0] # all users - first col of the Y_data
        self.Ybar_data = self.Y_data.copy()
        self.mu = np.zeros((self.n_users,))
        for n in range(self.n_users):
            # row indices of rating done by user n
            # since indices need to be integers, we need to convert
            ids = np.where(users == n)[0].astype(np.int32)
            # indices of all ratings associated with user n
            item_ids = self.Y_data[ids, 1]
            # and the corresponding ratings
            ratings = self.Y_data[ids, 2]
            # take mean
            m = np.mean(ratings)
            if np.isnan(m):
                m = 0 # to avoid empty array and nan value
            self.mu[n] = m
            # normalize
            self.Ybar_data[ids, 2] = ratings - self.mu[n]

        ################################################
        # form the rating matrix as a sparse matrix. Sparsity is important
        # for both memory and computing efficiency. For example, if #user = 1M,
        # #item = 100k, then shape of the rating matrix would be (100k, 1M),
        # you may not have enough memory to store this. Then, instead, we store
        # nonzeros only, and, of course, their locations.
        self.Ybar = sparse.coo_matrix((self.Ybar_data[:, 2],
            (self.Ybar_data[:, 1], self.Ybar_data[:, 0])), (self.n_items, self.n_users))
        self.Ybar = self.Ybar.tocsr()

    def similarity(self):
        eps = 1e-6
        self.S = self.dist_func(self.Ybar.T, self.Ybar.T)


    def refresh(self):
        """
        Normalize data and calculate similarity matrix again (after
        some few ratings added)
        """
        self.normalize_Y()
        self.similarity()

    def fit(self):
        self.refresh()


    def __pred(self, u, i, normalized = 1):
        """
        predict the rating of user u for item i (normalized)
        if you need the un
        """
        # Step 1: find all users who rated i
        ids = np.where(self.Y_data[:, 1] == i)[0].astype(np.int32)
        # Step 2:
        users_rated_i = (self.Y_data[ids, 0]).astype(np.int32)
        # Step 3: find similarity btw the current user and others
        # who already rated i
        sim = self.S[u, users_rated_i]
        # Step 4: find the k most similarity users
        a = np.argsort(sim)[-self.k:]
        # and the corresponding similarity levels
        nearest_s = sim[a]
        # How did each of 'near' users rated item i
        r = self.Ybar[i, users_rated_i[a]]
        if normalized:
            # add a small number, for instance, 1e-8, to avoid dividing by 0
            return (r*nearest_s)[0]/(np.abs(nearest_s).sum() + 1e-8)

        return (r*nearest_s)[0]/(np.abs(nearest_s).sum() + 1e-8) + self.mu[u]

    def pred(self, u, i, normalized = 1):
        """
        predict the rating of user u for item i (normalized)
        if you need the un
        """
        if self.uuCF:
            pred_rating = self.__pred(u, i, normalized)
        else:
            pred_rating = self.__pred(i, u, normalized)

        # Nếu xếp hạng dự đoán lớn hơn 5, trả về 5; ngược lại, trả về xếp hạng dự đoán
        return min(pred_rating, 5)


    def recommend(self, u):
        """
        Determine all items should be recommended for user u.
        The decision is made based on all i such that:
        self.pred(u, i) > 0. Suppose we are considering items which
        have not been rated by u yet.
        """
        ids = np.where(self.Y_data[:, 0] == u)[0]
        items_rated_by_u = self.Y_data[ids, 1].tolist()
        recommended_items = []
        for i in range(self.n_items):
            if i not in items_rated_by_u:
                rating = self.__pred(u, i)
                if rating > 0:
                    recommended_items.append(i)

        return recommended_items

    def recommend2(self, u):
        """
        Determine all items should be recommended for user u.
        The decision is made based on all i such that:
        self.pred(u, i) > 0. Suppose we are considering items which
        have not been rated by u yet.
        """
        ids = np.where(self.Y_data[:, 0] == u)[0]
        items_rated_by_u = self.Y_data[ids, 1].tolist()
        recommended_items = []

        for i in range(self.n_items):
            if i not in items_rated_by_u:
                rating = self.__pred(u, i)
                if rating > 0:
                    recommended_items.append(i)

        return recommended_items

    def recommend_top_k(self, u, top_k):
        """
        Recommend top 5 films with the highest predicted ratings for user u.
        """
        ids = np.where(self.Y_data[:, 0] == u)[0]
        items_rated_by_u = self.Y_data[ids, 1].tolist()
        recommended_items = []

        for i in range(self.n_items):
            if i not in items_rated_by_u:
                rating = self.pred(u, i, 0)
                if rating > 0:
                    recommended_items.append((i, rating))

        recommended_items.sort(key=lambda x: x[1], reverse=True)

        top_k_recommendations = recommended_items[:top_k]

        return top_k_recommendations

    def get_ratings_predict(self):
        """
        Recommend predicted ratings for all users and items.
        """
        all_recommendations = []

        for u in range(self.n_users):
            for i in range(self.n_items):
                rating = self.pred(u, i, 0)
                if rating > 0:
                    print("user_id:", u, "item_id:", i, "rating:", rating)
                    all_recommendations.append((u, i, rating))

        if all_recommendations:
            self.predict = pd.DataFrame(all_recommendations, columns=['user_id', 'item_id', 'predicted_rating'])
        else:
            self.predict = None

        return self.predict

    def print_recommendation(self):
        """
        print all items which should be recommended for each user
        """
        print('Recommendation: ')
        for u in range(self.n_users):
            recommended_items = self.recommend(u)
            if self.uuCF:
                print('    Recommend item(s):', recommended_items, 'for user', u)
            else:
                print('    Recommend item', u, 'for user(s) : ', recommended_items)

# %% [markdown]
# ## Tập dữ liệu

# %%
r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']

ratings_base = pd.read_csv('/content/drive/MyDrive/Recommendation-System/data/ml-100k/ua.base', sep='\t', names=r_cols, encoding='latin-1')
ratings_test = pd.read_csv('/content/drive/MyDrive/Recommendation-System/data/ml-100k/ub.test', sep='\t', names=r_cols, encoding='latin-1')

rate_train = ratings_base.values
rate_test = ratings_test.values

# indices start from 0
rate_train[:, :2] -= 1
rate_test[:, :2] -= 1

# %%
rs = CF(rate_train, k=30, uuCF=1)
rs.fit()

n_tests = rate_test.shape[0]
SE = 0  # squared error
for n in range(n_tests):
    pred = rs.pred(rate_test[n, 0], rate_test[n, 1], normalized=0)
    SE += (pred - rate_test[n, 2]) ** 2

RMSE = np.sqrt(SE / n_tests)
print('User-user CF, RMSE =', RMSE)
# Out:
# User-user CF, RMSE = 0.6952000543773251

# %%
from sklearn.metrics import r2_score

# Các giá trị thực tế
y_true = rate_test[:, 2]

# Các giá trị dự đoán
y_pred = np.array([rs.pred(rate_test[n, 0], rate_test[n, 1], normalized=0) for n in range(n_tests)])

# Tính R-squared
r_squared = r2_score(y_true, y_pred)

print('R-squared =', r_squared)
# Out:
# R-squared = 0.6172745239283569

# %%
ratings_predict = rs.get_ratings_predict()
ratings_predict
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# user_id: 940 item_id: 46 rating: 3.816021044135729
# user_id: 940 item_id: 47 rating: 4.0748054009126085
# user_id: 940 item_id: 48 rating: 3.7056125305658165
# user_id: 940 item_id: 49 rating: 4.195459404372217
# user_id: 940 item_id: 50 rating: 3.6646798061418333
# user_id: 940 item_id: 51 rating: 3.9971107476796903
# user_id: 940 item_id: 52 rating: 3.7664910240196554
# user_id: 940 item_id: 53 rating: 3.7455106453271543
# user_id: 940 item_id: 54 rating: 3.9280722792086102
# user_id: 940 item_id: 55 rating: 3.9685119312902652
# user_id: 940 item_id: 56 rating: 4.036504532235128
# user_id: 940 item_id: 57 rating: 3.960226596681343
# user_id: 940 item_id: 58 rating: 4.211240652227531
# user_id: 940 item_id: 59 rating: 4.106970722814214
# user_id: 940 item_id: 60 rating: 4.163496917229642
# user_id: 940 item_id: 61 rating: 3.6750348057486697
# user_id: 940 item_id: 62 rating: 3.6515551195704425
# user_id: 940 item_id: 63 rating: 4.30301396785076
# user_id: 940 item_id: 64 rating: 3.7280578246869984
# user_id: 940 item_id: 65 rating: 3.856775142594234
# user_id: 940 item_id: 66 rating: 3.462075463984378
# user_id: 940 item_id: 67 rating: 3.62805422008684
# user_id: 940 item_id: 68 rating: 3.8861925108543818
# user_id: 940 item_id: 69 rating: 3.7465305559969186
# user_id: 940 item_id: 70 rating: 3.892590851936509
# user_id: 940 item_id: 71 rating: 3.729108267380134
# user_id: 940 item_id: 72 rating: 3.8670512557829255
# user_id: 940 item_id: 73 rating: 3.6288605395213067
# user_id: 940 item_id: 74 rating: 3.8333333333333335
# user_id: 940 item_id: 75 rating: 3.5947703156616044
# user_id: 940 item_id: 76 rating: 3.6738955278054983
# user_id: 940 item_id: 77 rating: 3.4854718274264522
# user_id: 940 item_id: 78 rating: 3.8150538498027626
# user_id: 940 item_id: 79 rating: 3.5681317318160692
# user_id: 940 item_id: 80 rating: 3.8640295725716634
# user_id: 940 item_id: 81 rating: 3.9131998881374557
# user_id: 940 item_id: 82 rating: 4.060203753374908
# user_id: 940 item_id: 83 rating: 3.7298521106721845
# user_id: 940 item_id: 84 rating: 3.5795649573434196
# user_id: 940 item_id: 85 rating: 3.9989143976053025
# user_id: 940 item_id: 86 rating: 3.894984235887598
# user_id: 940 item_id: 87 rating: 3.6222589151675533
# user_id: 940 item_id: 88 rating: 4.230125723697569
# user_id: 940 item_id: 89 rating: 3.6459764847068614
# user_id: 940 item_id: 90 rating: 3.856830240553343
# user_id: 940 item_id: 91 rating: 3.8578635058872135
# user_id: 940 item_id: 92 rating: 4.023541768291119
# user_id: 940 item_id: 93 rating: 3.693028534639361
# user_id: 940 item_id: 94 rating: 3.9679985995493237
# user_id: 940 item_id: 95 rating: 4.070608627264553
# user_id: 940 item_id: 96 rating: 3.6943845833291027
# user_id: 940 item_id: 97 rating: 4.4056935594136455
# user_id: 940 item_id: 98 rating: 3.977189495246382
# user_id: 940 item_id: 99 rating: 4.370924727496491
# user_id: 940 item_id: 100 rating: 3.7318147379902884
# user_id: 940 item_id: 101 rating: 3.6619323597162814
# user_id: 940 item_id: 102 rating: 3.1969311315238125
# user_id: 940 item_id: 103 rating: 2.6545598925077103
# user_id: 940 item_id: 104 rating: 3.3193183418796597
# user_id: 940 item_id: 105 rating: 3.5509794556071443
# user_id: 940 item_id: 106 rating: 3.3930718118561454
# user_id: 940 item_id: 107 rating: 3.5849922610973133
# user_id: 940 item_id: 108 rating: 3.982345327680948
# user_id: 940 item_id: 109 rating: 3.901969286699945
# user_id: 940 item_id: 110 rating: 3.755532471804247
# user_id: 940 item_id: 111 rating: 3.742388910116864
# user_id: 940 item_id: 112 rating: 4.053158167796607
# user_id: 940 item_id: 113 rating: 4.627791189919039
# user_id: 940 item_id: 114 rating: 4.5497015504349365
# user_id: 940 item_id: 115 rating: 3.9504906652207263
# user_id: 940 item_id: 116 rating: 3.8026579030841083
# user_id: 940 item_id: 117 rating: 3.4446419973836875
# user_id: 940 item_id: 118 rating: 4.157744393574568
# user_id: 940 item_id: 119 rating: 2.7135600748000286
# user_id: 940 item_id: 120 rating: 3.648422887852295
# user_id: 940 item_id: 121 rating: 3.192239423588387
# user_id: 940 item_id: 122 rating: 3.6776047949184467
# user_id: 940 item_id: 123 rating: 4.0700684463147345
# user_id: 940 item_id: 124 rating: 3.6646202038110256
# user_id: 940 item_id: 125 rating: 4.36229521282479
# user_id: 940 item_id: 126 rating: 4.410196986702272
# user_id: 940 item_id: 127 rating: 3.9725630511024783
# user_id: 940 item_id: 128 rating: 3.879673731326429
# user_id: 940 item_id: 129 rating: 3.4313704031998475
# user_id: 940 item_id: 130 rating: 3.6101783584949887
# user_id: 940 item_id: 131 rating: 4.148811225913434
# user_id: 940 item_id: 132 rating: 4.001613580131588
# user_id: 940 item_id: 133 rating: 4.261634272452585
# user_id: 940 item_id: 134 rating: 4.069173061135983
# user_id: 940 item_id: 135 rating: 4.163068323605083
# user_id: 940 item_id: 136 rating: 4.163516574292993
# user_id: 940 item_id: 137 rating: 3.921189673174422
# user_id: 940 item_id: 138 rating: 3.508622112877497
# user_id: 940 item_id: 139 rating: 3.642555299802361
# user_id: 940 item_id: 140 rating: 3.7888421941134407
# user_id: 940 item_id: 141 rating: 3.5439518517755326
# user_id: 940 item_id: 142 rating: 3.8756281858138215
# user_id: 940 item_id: 143 rating: 3.923434900769402
# user_id: 940 item_id: 144 rating: 3.20279750914189
# user_id: 940 item_id: 145 rating: 3.591273562165458
# user_id: 940 item_id: 146 rating: 3.659134981910933
# user_id: 940 item_id: 147 rating: 3.4551951798564704
# user_id: 940 item_id: 148 rating: 3.913353918012573
# user_id: 940 item_id: 149 rating: 3.988360546671957
# user_id: 940 item_id: 150 rating: 4.016027667894976
# user_id: 940 item_id: 151 rating: 4.033865858407683
# user_id: 940 item_id: 152 rating: 3.999000388654635
# user_id: 940 item_id: 153 rating: 4.028392219400175
# user_id: 940 item_id: 154 rating: 3.567336282968724
# user_id: 940 item_id: 155 rating: 3.9848136391061493
# user_id: 940 item_id: 156 rating: 4.15057353213081
# user_id: 940 item_id: 157 rating: 3.4177412938115705
# user_id: 940 item_id: 158 rating: 3.7967097102997274
# user_id: 940 item_id: 159 rating: 3.8302280291614426
# user_id: 940 item_id: 160 rating: 3.9854995722502724
# user_id: 940 item_id: 161 rating: 3.735374549127769
# user_id: 940 item_id: 162 rating: 4.0505216353290585
# user_id: 940 item_id: 163 rating: 3.774498892343995
# user_id: 940 item_id: 164 rating: 4.145964651752037
# user_id: 940 item_id: 165 rating: 4.256405845111605
# user_id: 940 item_id: 166 rating: 3.5504740249399718
# user_id: 940 item_id: 167 rating: 4.315092224021731
# user_id: 940 item_id: 168 rating: 4.605076578925994
# user_id: 940 item_id: 169 rating: 4.198951083853714
# user_id: 940 item_id: 170 rating: 4.263829800997918
# user_id: 940 item_id: 171 rating: 4.177373414643812
# user_id: 940 item_id: 172 rating: 4.320724283102871
# user_id: 940 item_id: 173 rating: 4.28392970555036
# user_id: 940 item_id: 174 rating: 4.012975620232586
# user_id: 940 item_id: 175 rating: 4.016861253284938
# user_id: 940 item_id: 176 rating: 3.9730634217583036
# user_id: 940 item_id: 177 rating: 4.277239478973196
# user_id: 940 item_id: 178 rating: 3.939800950608638
# user_id: 940 item_id: 179 rating: 4.0172015008390325
# user_id: 940 item_id: 180 rating: 4.1400614098259885
# user_id: 940 item_id: 181 rating: 3.988190365513298
# user_id: 940 item_id: 182 rating: 4.15750959155366
# user_id: 940 item_id: 183 rating: 4.039242298173936
# user_id: 940 item_id: 184 rating: 4.309863077963708
# user_id: 940 item_id: 185 rating: 4.153179882229225
# user_id: 940 item_id: 186 rating: 4.270007831749077
# user_id: 940 item_id: 187 rating: 3.8416117361881272
# user_id: 940 item_id: 188 rating: 4.329998613155342
# user_id: 940 item_id: 189 rating: 4.161497254507515
# user_id: 940 item_id: 190 rating: 4.070063942945159
# user_id: 940 item_id: 191 rating: 4.0536391917988
# user_id: 940 item_id: 192 rating: 4.07203937615229
# user_id: 940 item_id: 193 rating: 4.105711215425079
# user_id: 940 item_id: 194 rating: 3.915435621852556
# user_id: 940 item_id: 195 rating: 4.1196727508250195
# user_id: 940 item_id: 196 rating: 3.9126041900522597
# user_id: 940 item_id: 197 rating: 4.285316107996051
# user_id: 940 item_id: 198 rating: 4.220167398845226
# user_id: 940 item_id: 199 rating: 4.111379401648432
# user_id: 940 item_id: 200 rating: 4.34655617390349
# user_id: 940 item_id: 201 rating: 3.9843887609012882
# user_id: 940 item_id: 202 rating: 4.059505571418611
# user_id: 940 item_id: 203 rating: 4.0389764607377625
# user_id: 940 item_id: 204 rating: 4.169049966602387
# user_id: 940 item_id: 205 rating: 3.838998203010542
# user_id: 940 item_id: 206 rating: 4.067479189542987
# user_id: 940 item_id: 207 rating: 4.0143647610104685
# user_id: 940 item_id: 208 rating: 4.1359556995070985
# user_id: 940 item_id: 209 rating: 4.017086685577402
# user_id: 940 item_id: 210 rating: 3.961460983904994
# user_id: 940 item_id: 211 rating: 3.652064729251318
# user_id: 940 item_id: 212 rating: 4.081305993681112
# user_id: 940 item_id: 213 rating: 3.7236653178917174
# user_id: 940 item_id: 214 rating: 3.833677047868335
# user_id: 940 item_id: 215 rating: 4.155958296460093
# user_id: 940 item_id: 216 rating: 3.629377935466492
# user_id: 940 item_id: 217 rating: 3.84217268266642
# user_id: 940 item_id: 218 rating: 3.421128930746992
# user_id: 940 item_id: 219 rating: 3.8674868911009463
# user_id: 940 item_id: 220 rating: 3.869495906012057
# user_id: 940 item_id: 221 rating: 3.0730455132553396
# user_id: 940 item_id: 222 rating: 4.145455547607737
# user_id: 940 item_id: 223 rating: 4.287627191735108
# user_id: 940 item_id: 224 rating: 3.5497342851190274
# user_id: 940 item_id: 225 rating: 3.797869743967766
# user_id: 940 item_id: 226 rating: 3.6496532652411777
# user_id: 940 item_id: 227 rating: 4.090255211119421
# user_id: 940 item_id: 228 rating: 3.740152536227373
# user_id: 940 item_id: 229 rating: 3.7874653178187074
# user_id: 940 item_id: 230 rating: 3.4548097899743433
# user_id: 940 item_id: 231 rating: 3.767287329005135
# user_id: 940 item_id: 232 rating: 3.6676492777119916
# user_id: 940 item_id: 233 rating: 4.016445537352847
# user_id: 940 item_id: 234 rating: 3.48573600348249
# user_id: 940 item_id: 235 rating: 3.9395661884828095
# user_id: 940 item_id: 236 rating: 3.8946081287331853
# user_id: 940 item_id: 237 rating: 4.111817749847691
# user_id: 940 item_id: 238 rating: 3.86299965561191
# user_id: 940 item_id: 239 rating: 3.709737995525594
# user_id: 940 item_id: 240 rating: 3.8392400512783107
# user_id: 940 item_id: 241 rating: 4.19362785322299
# user_id: 940 item_id: 242 rating: 3.009115538457971
# user_id: 940 item_id: 243 rating: 3.8810831323560904
# user_id: 940 item_id: 244 rating: 3.456435617679588
# user_id: 940 item_id: 245 rating: 4.083552716048572
# user_id: 940 item_id: 246 rating: 3.0279517854166533
# user_id: 940 item_id: 247 rating: 3.806782364185041
# user_id: 940 item_id: 248 rating: 3.7494883083727486
# user_id: 940 item_id: 249 rating: 3.763804958009167
# user_id: 940 item_id: 250 rating: 4.4322501249877275
# user_id: 940 item_id: 251 rating: 3.3491132613387404
# user_id: 940 item_id: 252 rating: 3.56838048212293
# user_id: 940 item_id: 253 rating: 3.222716603595092
# user_id: 940 item_id: 254 rating: 3.756086308886156
# user_id: 940 item_id: 255 rating: 4.0829652900446805
# user_id: 940 item_id: 256 rating: 3.9659059475565903
# user_id: 940 item_id: 257 rating: 3.930865415811057
# user_id: 940 item_id: 258 rating: 3.512961347753998
# user_id: 940 item_id: 259 rating: 2.9846381561443445
# user_id: 940 item_id: 260 rating: 2.797509835678604
# user_id: 940 item_id: 261 rating: 4.423857704882674
# user_id: 940 item_id: 262 rating: 3.1815865372396726
# user_id: 940 item_id: 263 rating: 3.1616442445984947
# user_id: 940 item_id: 264 rating: 3.9686267018968686
# user_id: 940 item_id: 265 rating: 3.3950485458781494
# user_id: 940 item_id: 266 rating: 4.132418860882772
# user_id: 940 item_id: 267 rating: 4.249159834067821
# user_id: 940 item_id: 268 rating: 4.046816735078604
# user_id: 940 item_id: 269 rating: 3.824629143897006
# user_id: 940 item_id: 270 rating: 3.5548495685715067
# user_id: 940 item_id: 271 rating: 4.490952727870279
# user_id: 940 item_id: 272 rating: 4.006967140232033
# user_id: 940 item_id: 273 rating: 3.9082819308801007
# user_id: 940 item_id: 274 rating: 4.064418443652634
# user_id: 940 item_id: 275 rating: 3.940415108636008
# user_id: 940 item_id: 276 rating: 3.5331293143821707
# user_id: 940 item_id: 277 rating: 3.6355776732182368
# user_id: 940 item_id: 278 rating: 4.046753169058466
# user_id: 940 item_id: 279 rating: 3.667578078923055
# user_id: 940 item_id: 280 rating: 3.752109595940646
# user_id: 940 item_id: 281 rating: 3.9944386081160497
# user_id: 940 item_id: 282 rating: 3.929809613956814
# user_id: 940 item_id: 283 rating: 3.6670853957327587
# user_id: 940 item_id: 284 rating: 4.385590386673734
# user_id: 940 item_id: 285 rating: 3.9965369853715003
# user_id: 940 item_id: 286 rating: 3.954264047650273
# user_id: 940 item_id: 287 rating: 3.759850047097459
# user_id: 940 item_id: 288 rating: 3.6392023446889863
# user_id: 940 item_id: 289 rating: 3.5467279251169
# user_id: 940 item_id: 290 rating: 3.853350845644857
# user_id: 940 item_id: 291 rating: 3.4295251927945922
# user_id: 940 item_id: 292 rating: 4.049572858306308
# user_id: 940 item_id: 293 rating: 3.7798551681567685
# user_id: 940 item_id: 294 rating: 3.647274282278402
# user_id: 940 item_id: 295 rating: 4.833333261191058
# user_id: 940 item_id: 296 rating: 3.883726549522611
# user_id: 940 item_id: 297 rating: 4.630465061379617
# user_id: 940 item_id: 298 rating: 3.3984069538001673
# user_id: 940 item_id: 299 rating: 3.930345344019502
# user_id: 940 item_id: 300 rating: 3.575659261307799
# user_id: 940 item_id: 301 rating: 4.084086788554512
# user_id: 940 item_id: 302 rating: 3.921327751190172
# user_id: 940 item_id: 303 rating: 3.858741992108324
# user_id: 940 item_id: 304 rating: 3.9994168914343526
# user_id: 940 item_id: 305 rating: 3.9826320114480076
# user_id: 940 item_id: 306 rating: 3.656896198562287
# user_id: 940 item_id: 307 rating: 3.6043219586446797
# user_id: 940 item_id: 308 rating: 4.5941751365134555
# user_id: 940 item_id: 309 rating: 3.9886138128225865
# user_id: 940 item_id: 310 rating: 4.005607558224182
# user_id: 940 item_id: 311 rating: 3.468225198808503
# user_id: 940 item_id: 312 rating: 4.469120302487049
# user_id: 940 item_id: 313 rating: 2.8333336882979943
# user_id: 940 item_id: 314 rating: 4.08190483843852
# user_id: 940 item_id: 315 rating: 4.042106312256918
# user_id: 940 item_id: 316 rating: 3.9736330022364617
# user_id: 940 item_id: 317 rating: 4.402649753074319
# user_id: 940 item_id: 318 rating: 3.6089220048232327
# user_id: 940 item_id: 319 rating: 4.508913204688402
# user_id: 940 item_id: 320 rating: 3.771904867604917
# user_id: 940 item_id: 321 rating: 3.375343847583947
# user_id: 940 item_id: 322 rating: 3.363880280945633
# user_id: 940 item_id: 323 rating: 3.654551679221063
# user_id: 940 item_id: 324 rating: 3.4507680907234612
# user_id: 940 item_id: 325 rating: 3.8342107520178015
# user_id: 940 item_id: 326 rating: 3.7795047218987383
# user_id: 940 item_id: 327 rating: 3.601901218326723
# user_id: 940 item_id: 328 rating: 3.598401482462883
# user_id: 940 item_id: 329 rating: 3.700831473967184
# user_id: 940 item_id: 330 rating: 3.807340801092842
# user_id: 940 item_id: 331 rating: 3.712413343265589
# user_id: 940 item_id: 332 rating: 3.9171830092265414
# user_id: 940 item_id: 333 rating: 3.810434746540354
# user_id: 940 item_id: 334 rating: 2.9308315322791114
# user_id: 940 item_id: 335 rating: 2.9197948654516046
# user_id: 940 item_id: 336 rating: 4.165153146799269
# user_id: 940 item_id: 337 rating: 3.319886361710029
# user_id: 940 item_id: 338 rating: 3.597651156529067
# user_id: 940 item_id: 339 rating: 3.740070754899535
# user_id: 940 item_id: 340 rating: 3.8333333333333335
# user_id: 940 item_id: 341 rating: 3.1231403367676718
# user_id: 940 item_id: 342 rating: 3.671032553873464
# user_id: 940 item_id: 343 rating: 3.6266318730900364
# user_id: 940 item_id: 344 rating: 3.7559830170063955
# user_id: 940 item_id: 345 rating: 3.9023474609709554
# user_id: 940 item_id: 346 rating: 3.923255182685116
# user_id: 940 item_id: 347 rating: 2.914736580247741
# user_id: 940 item_id: 348 rating: 3.1290102872207384
# user_id: 940 item_id: 349 rating: 3.5662304640141005
# user_id: 940 item_id: 350 rating: 3.573428618703877
# user_id: 940 item_id: 351 rating: 3.5459305041147506
# user_id: 940 item_id: 352 rating: 2.6094545063324484
# user_id: 940 item_id: 353 rating: 3.7643478738995557
# user_id: 940 item_id: 354 rating: 3.3221597144042425
# user_id: 940 item_id: 355 rating: 3.742614779693652
# user_id: 940 item_id: 356 rating: 4.062105389549154
# user_id: 940 item_id: 357 rating: 2.3469797948966633
# user_id: 940 item_id: 358 rating: 3.738970561378272
# user_id: 940 item_id: 359 rating: 3.700767037980226
# user_id: 940 item_id: 360 rating: 2.8333335292924744
# user_id: 940 item_id: 361 rating: 4.0278980834410145
# user_id: 940 item_id: 362 rating: 3.016931608754962
# user_id: 940 item_id: 363 rating: 3.235155338678027
# user_id: 940 item_id: 364 rating: 3.8574598408011633
# user_id: 940 item_id: 365 rating: 3.717390990162789
# user_id: 940 item_id: 366 rating: 3.91288079801659
# user_id: 940 item_id: 367 rating: 2.7851747705617544
# user_id: 940 item_id: 368 rating: 3.0817639935923253
# user_id: 940 item_id: 369 rating: 3.2867750714691533
# user_id: 940 item_id: 370 rating: 3.715275321166635
# user_id: 940 item_id: 371 rating: 4.11017634081721
# user_id: 940 item_id: 372 rating: 3.5824852537773513
# user_id: 940 item_id: 373 rating: 2.8229677511442093
# user_id: 940 item_id: 374 rating: 2.8131650530258314
# user_id: 940 item_id: 375 rating: 3.346026975371161
# user_id: 940 item_id: 376 rating: 3.17779465461159
# user_id: 940 item_id: 377 rating: 3.9835473657266984
# user_id: 940 item_id: 378 rating: 3.6513578511730134
# user_id: 940 item_id: 379 rating: 3.7333961767267474
# user_id: 940 item_id: 380 rating: 3.8866193451700797
# user_id: 940 item_id: 381 rating: 3.8905157634730783
# user_id: 940 item_id: 382 rating: 3.368367226495472
# user_id: 940 item_id: 383 rating: 3.6093430944097755
# user_id: 940 item_id: 384 rating: 3.622543435094832
# user_id: 940 item_id: 385 rating: 3.597575582608141
# user_id: 940 item_id: 386 rating: 3.80738361534255
# user_id: 940 item_id: 387 rating: 3.579294805619399
# user_id: 940 item_id: 388 rating: 3.8840831958778463
# user_id: 940 item_id: 389 rating: 4.1862046894763285
# user_id: 940 item_id: 390 rating: 3.419196918246639
# user_id: 940 item_id: 391 rating: 3.707175331816697
# user_id: 940 item_id: 392 rating: 3.7347482181626845
# user_id: 940 item_id: 393 rating: 4.572769907548636
# user_id: 940 item_id: 394 rating: 3.410255557383708
# user_id: 940 item_id: 395 rating: 3.8585141038318653
# user_id: 940 item_id: 396 rating: 3.059739824992094
# user_id: 940 item_id: 397 rating: 3.266870051804383
# user_id: 940 item_id: 398 rating: 3.6812864156855842
# user_id: 940 item_id: 399 rating: 3.5220811982149898
# user_id: 940 item_id: 400 rating: 3.6478837083291595
# user_id: 940 item_id: 401 rating: 3.673990334491336
# user_id: 940 item_id: 402 rating: 3.6795339368572497
# user_id: 940 item_id: 403 rating: 3.8116619895670354
# user_id: 940 item_id: 404 rating: 3.586890524464029
# user_id: 940 item_id: 405 rating: 3.1032694356481505
# user_id: 940 item_id: 406 rating: 3.330826734368864
# user_id: 940 item_id: 407 rating: 4.873784395812065
# user_id: 940 item_id: 408 rating: 3.4457293717491275
# user_id: 940 item_id: 409 rating: 3.7866675041989892
# user_id: 940 item_id: 410 rating: 3.5178338468851575
# user_id: 940 item_id: 411 rating: 3.3159548234033167
# user_id: 940 item_id: 412 rating: 3.5472884709525703
# user_id: 940 item_id: 413 rating: 3.9435897708004135
# user_id: 940 item_id: 414 rating: 3.965653024421115
# user_id: 940 item_id: 415 rating: 3.849766394129273
# user_id: 940 item_id: 416 rating: 3.650381972887282
# user_id: 940 item_id: 417 rating: 3.8261241616803097
# user_id: 940 item_id: 418 rating: 4.038768606852623
# user_id: 940 item_id: 419 rating: 4.098459996363615
# user_id: 940 item_id: 420 rating: 3.878652299182241
# user_id: 940 item_id: 421 rating: 3.62035729931229
# user_id: 940 item_id: 422 rating: 4.104961789510926
# user_id: 940 item_id: 423 rating: 2.7351391500746285
# user_id: 940 item_id: 424 rating: 4.018806285219037
# user_id: 940 item_id: 425 rating: 4.051931824548165
# user_id: 940 item_id: 426 rating: 4.347756138070793
# user_id: 940 item_id: 427 rating: 3.9675677589154783
# user_id: 940 item_id: 428 rating: 3.973195997104922
# user_id: 940 item_id: 429 rating: 4.205318284352357
# user_id: 940 item_id: 430 rating: 3.695290938590465
# user_id: 940 item_id: 431 rating: 3.959480164624542
# user_id: 940 item_id: 432 rating: 4.211138075427637
# user_id: 940 item_id: 433 rating: 3.9011054817932327
# user_id: 940 item_id: 434 rating: 4.059764788086716
# user_id: 940 item_id: 435 rating: 3.950561238570425
# user_id: 940 item_id: 436 rating: 2.8333333755835346
# user_id: 940 item_id: 437 rating: 2.648346198019458
# user_id: 940 item_id: 438 rating: 2.8333333819817295
# user_id: 940 item_id: 439 rating: 2.3925012756729305
# user_id: 940 item_id: 440 rating: 3.3804007718921962
# user_id: 940 item_id: 441 rating: 2.8333336545807986
# user_id: 940 item_id: 442 rating: 4.068349668921846
# user_id: 940 item_id: 443 rating: 3.4761681134621756
# user_id: 940 item_id: 444 rating: 3.662674415045369
# user_id: 940 item_id: 445 rating: 3.8675006420508113
# user_id: 940 item_id: 446 rating: 3.6969957511893403
# user_id: 940 item_id: 447 rating: 4.015300512636103
# user_id: 940 item_id: 448 rating: 3.404723589406485
# user_id: 940 item_id: 449 rating: 2.88322844294213
# user_id: 940 item_id: 450 rating: 3.693383582969205
# user_id: 940 item_id: 451 rating: 3.615361456523087
# user_id: 940 item_id: 452 rating: 3.237515097706285
# user_id: 940 item_id: 453 rating: 4.240121865538246
# user_id: 940 item_id: 454 rating: 3.8730080845168913
# user_id: 940 item_id: 455 rating: 3.2493438650685755
# user_id: 940 item_id: 456 rating: 2.9913102730862
# user_id: 940 item_id: 457 rating: 3.725022448090452
# user_id: 940 item_id: 458 rating: 3.6358813253380613
# user_id: 940 item_id: 459 rating: 3.920979177221272
# user_id: 940 item_id: 460 rating: 3.7607530729663776
# user_id: 940 item_id: 461 rating: 3.765468481281726
# user_id: 940 item_id: 462 rating: 3.9280243711672234
# user_id: 940 item_id: 463 rating: 3.9157610397766094
# user_id: 940 item_id: 464 rating: 3.8160642771032065
# user_id: 940 item_id: 465 rating: 4.071936807223388
# user_id: 940 item_id: 466 rating: 4.195528224784958
# user_id: 940 item_id: 467 rating: 3.579484697934105
# user_id: 940 item_id: 468 rating: 3.848455867030179
# user_id: 940 item_id: 469 rating: 3.9990450925342023
# user_id: 940 item_id: 470 rating: 3.703760692160626
# user_id: 940 item_id: 471 rating: 3.390165028223202
# user_id: 940 item_id: 472 rating: 3.763273154326181
# user_id: 940 item_id: 473 rating: 4.2968923264254215
# user_id: 940 item_id: 474 rating: 3.979570192919388
# user_id: 940 item_id: 475 rating: 3.5133678161073054
# user_id: 940 item_id: 476 rating: 3.858811240977812
# user_id: 940 item_id: 477 rating: 4.03172107026935
# user_id: 940 item_id: 478 rating: 4.110834238407205
# user_id: 940 item_id: 479 rating: 4.324217913773886
# user_id: 940 item_id: 480 rating: 4.0409792774700835
# user_id: 940 item_id: 481 rating: 3.947655890129252
# user_id: 940 item_id: 482 rating: 4.255561820280846
# user_id: 940 item_id: 483 rating: 4.142060870586387
# user_id: 940 item_id: 484 rating: 4.119270090729398
# user_id: 940 item_id: 485 rating: 4.088698133516255
# user_id: 940 item_id: 486 rating: 4.169563308640887
# user_id: 940 item_id: 487 rating: 3.898210110220974
# user_id: 940 item_id: 488 rating: 4.188664339274737
# user_id: 940 item_id: 489 rating: 4.087382915248865
# user_id: 940 item_id: 490 rating: 3.9840817938386897
# user_id: 940 item_id: 491 rating: 3.8551096949623913
# user_id: 940 item_id: 492 rating: 4.250778474810339
# user_id: 940 item_id: 493 rating: 4.297756788785131
# user_id: 940 item_id: 494 rating: 3.8333333333333335
# user_id: 940 item_id: 495 rating: 4.134696856578676
# user_id: 940 item_id: 496 rating: 3.8017520753398415
# user_id: 940 item_id: 497 rating: 4.305927563285562
# user_id: 940 item_id: 498 rating: 3.930484220700776
# user_id: 940 item_id: 499 rating: 3.976396364698719
# user_id: 940 item_id: 500 rating: 3.8036222036665097
# user_id: 940 item_id: 501 rating: 4.103623126068971
# user_id: 940 item_id: 502 rating: 3.8396076212806505
# user_id: 940 item_id: 503 rating: 4.187733183650232
# user_id: 940 item_id: 504 rating: 3.9447927753812158
# user_id: 940 item_id: 505 rating: 3.9503926674294005
# user_id: 940 item_id: 506 rating: 3.9079578701610567
# user_id: 940 item_id: 507 rating: 3.9288615203430832
# user_id: 940 item_id: 508 rating: 3.9349243197151784
# user_id: 940 item_id: 509 rating: 4.054142813964612
# user_id: 940 item_id: 510 rating: 4.367002745410473
# user_id: 940 item_id: 511 rating: 4.4793943161543
# user_id: 940 item_id: 512 rating: 4.274733055719977
# user_id: 940 item_id: 513 rating: 4.191502829032866
# user_id: 940 item_id: 514 rating: 4.244983104501923
# user_id: 940 item_id: 515 rating: 4.028541323628113
# user_id: 940 item_id: 516 rating: 3.9613556962570224
# user_id: 940 item_id: 517 rating: 4.157864095154635
# user_id: 940 item_id: 518 rating: 4.133734162939754
# user_id: 940 item_id: 519 rating: 4.328813931287362
# user_id: 940 item_id: 520 rating: 4.044761709713362
# user_id: 940 item_id: 521 rating: 4.023669958296646
# user_id: 940 item_id: 522 rating: 4.017445758553654
# user_id: 940 item_id: 523 rating: 3.997266525386273
# user_id: 940 item_id: 524 rating: 4.138032357272192
# user_id: 940 item_id: 525 rating: 3.9780828267483384
# user_id: 940 item_id: 526 rating: 4.1821299153828
# user_id: 940 item_id: 527 rating: 3.936894913207254
# user_id: 940 item_id: 528 rating: 4.189930416952467
# user_id: 940 item_id: 529 rating: 4.0426433304581595
# user_id: 940 item_id: 530 rating: 4.010249790395904
# user_id: 940 item_id: 531 rating: 3.760307763881356
# user_id: 940 item_id: 532 rating: 3.8333333333333335
# user_id: 940 item_id: 533 rating: 3.952151058682614
# user_id: 940 item_id: 534 rating: 3.5729448803615895
# user_id: 940 item_id: 535 rating: 3.6314295285206457
# user_id: 940 item_id: 536 rating: 3.872374598410067
# user_id: 940 item_id: 537 rating: 4.036424379713667
# user_id: 940 item_id: 538 rating: 3.675494287913938
# user_id: 940 item_id: 539 rating: 3.0359056188521674
# user_id: 940 item_id: 540 rating: 3.530885457879388
# user_id: 940 item_id: 541 rating: 3.1935566363313557
# user_id: 940 item_id: 542 rating: 4.216948395731397
# user_id: 940 item_id: 543 rating: 3.405742613018483
# user_id: 940 item_id: 544 rating: 3.070360785412081
# user_id: 940 item_id: 545 rating: 3.2781939048351
# user_id: 940 item_id: 546 rating: 4.046755562618046
# user_id: 940 item_id: 547 rating: 3.8333333333333335
# user_id: 940 item_id: 548 rating: 3.838663428552481
# user_id: 940 item_id: 549 rating: 3.914452535876051
# user_id: 940 item_id: 550 rating: 3.310579313773585
# user_id: 940 item_id: 551 rating: 3.417239128804191
# user_id: 940 item_id: 552 rating: 4.151831035622051
# user_id: 940 item_id: 553 rating: 3.291114944295395
# user_id: 940 item_id: 554 rating: 2.0954790080944203
# user_id: 940 item_id: 555 rating: 3.879761653763792
# user_id: 940 item_id: 556 rating: 3.4867792888328
# user_id: 940 item_id: 557 rating: 4.019880378352514
# user_id: 940 item_id: 558 rating: 3.4545145016641268
# user_id: 940 item_id: 559 rating: 3.838862788548565
# user_id: 940 item_id: 560 rating: 3.450147627725672
# user_id: 940 item_id: 561 rating: 3.901211891740759
# user_id: 940 item_id: 562 rating: 3.740219515499764
# user_id: 940 item_id: 563 rating: 3.7523876196765236
# user_id: 940 item_id: 564 rating: 3.6223276013806056
# user_id: 940 item_id: 565 rating: 3.7988007585904544
# user_id: 940 item_id: 566 rating: 3.6028158903132046
# user_id: 940 item_id: 567 rating: 3.8178926486005564
# user_id: 940 item_id: 568 rating: 3.5575249100714728
# user_id: 940 item_id: 569 rating: 3.5296457142294355
# user_id: 940 item_id: 570 rating: 3.347764347074451
# user_id: 940 item_id: 571 rating: 3.4293024644458496
# user_id: 940 item_id: 572 rating: 3.7833114372400263
# user_id: 940 item_id: 573 rating: 3.339368098878085
# user_id: 940 item_id: 574 rating: 3.268458830560255
# user_id: 940 item_id: 575 rating: 3.703553513478057
# user_id: 940 item_id: 576 rating: 2.8142896496088223
# user_id: 940 item_id: 577 rating: 3.676095097747768
# user_id: 940 item_id: 578 rating: 3.472948034300689
# user_id: 940 item_id: 579 rating: 3.9297528455777164
# user_id: 940 item_id: 580 rating: 3.672810416192554
# user_id: 940 item_id: 581 rating: 3.377288834402614
# user_id: 940 item_id: 582 rating: 3.644190314345774
# user_id: 940 item_id: 583 rating: 3.9860534535732746
# user_id: 940 item_id: 584 rating: 3.1451225398996483
# user_id: 940 item_id: 585 rating: 3.336684865839199
# user_id: 940 item_id: 586 rating: 3.8333333333333335
# user_id: 940 item_id: 587 rating: 3.885627787345927
# user_id: 940 item_id: 588 rating: 4.1733498380992
# user_id: 940 item_id: 589 rating: 3.1926182838453325
# user_id: 940 item_id: 590 rating: 3.9035633772974103
# user_id: 940 item_id: 591 rating: 3.8333333333333335
# user_id: 940 item_id: 592 rating: 3.8333333333333335
# user_id: 940 item_id: 593 rating: 3.1397058909092954
# user_id: 940 item_id: 594 rating: 3.8347683615627797
# user_id: 940 item_id: 595 rating: 3.7862494749981317
# user_id: 940 item_id: 596 rating: 3.708443650699057
# user_id: 940 item_id: 597 rating: 3.8333333333333335
# user_id: 940 item_id: 598 rating: 3.8333333333333335
# user_id: 940 item_id: 599 rating: 3.8333333333333335
# user_id: 940 item_id: 600 rating: 3.7003811193493683
# user_id: 940 item_id: 601 rating: 3.977793765110137
# user_id: 940 item_id: 602 rating: 4.3041611983049055
# user_id: 940 item_id: 603 rating: 4.010952136563002
# user_id: 940 item_id: 604 rating: 3.8795106189733297
# user_id: 940 item_id: 605 rating: 4.1051536662474675
# user_id: 940 item_id: 606 rating: 3.99930298369582
# user_id: 940 item_id: 607 rating: 4.247483808405271
# user_id: 940 item_id: 608 rating: 3.8901495993419224
# user_id: 940 item_id: 609 rating: 3.6212908944327937
# user_id: 940 item_id: 610 rating: 4.325085204839319
# user_id: 940 item_id: 611 rating: 4.271457532180838
# user_id: 940 item_id: 612 rating: 4.284072567288446
# user_id: 940 item_id: 613 rating: 3.959108183556092
# user_id: 940 item_id: 614 rating: 3.947186142048966
# user_id: 940 item_id: 615 rating: 3.443620531036911
# user_id: 940 item_id: 616 rating: 3.9832931221984307
# user_id: 940 item_id: 617 rating: 3.698362845117127
# user_id: 940 item_id: 618 rating: 3.464478320686234
# user_id: 940 item_id: 619 rating: 3.6220346830958006
# user_id: 940 item_id: 620 rating: 3.4806824712982953
# user_id: 940 item_id: 621 rating: 3.7392477060658695
# user_id: 940 item_id: 622 rating: 3.724231880183733
# user_id: 940 item_id: 623 rating: 3.5097649788852636
# user_id: 940 item_id: 624 rating: 3.665911185931731
# user_id: 940 item_id: 625 rating: 3.8333333333333335
# user_id: 940 item_id: 626 rating: 3.7567702167611823
# user_id: 940 item_id: 627 rating: 3.7723256326096424
# user_id: 940 item_id: 628 rating: 3.763802482559538
# user_id: 940 item_id: 629 rating: 3.848674837455012
# user_id: 940 item_id: 630 rating: 3.8337522289489954
# user_id: 940 item_id: 631 rating: 4.0351794979964035
# user_id: 940 item_id: 632 rating: 3.9395500220552644
# user_id: 940 item_id: 633 rating: 3.9666019010669666
# user_id: 940 item_id: 634 rating: 4.080211497947725
# user_id: 940 item_id: 635 rating: 3.6409506166778893
# user_id: 940 item_id: 636 rating: 4.114000362969908
# user_id: 940 item_id: 637 rating: 4.078878937122539
# user_id: 940 item_id: 638 rating: 3.6755882631552073
# user_id: 940 item_id: 639 rating: 3.7144392684837904
# user_id: 940 item_id: 640 rating: 3.9971660579628976
# user_id: 940 item_id: 641 rating: 3.720002706729681
# user_id: 940 item_id: 642 rating: 3.8333333333333335
# user_id: 940 item_id: 643 rating: 3.739812423429422
# user_id: 940 item_id: 644 rating: 4.033013357014715
# user_id: 940 item_id: 645 rating: 4.494803940878432
# user_id: 940 item_id: 646 rating: 4.023993926917787
# user_id: 940 item_id: 647 rating: 4.196458669115002
# user_id: 940 item_id: 648 rating: 3.6466551761331454
# user_id: 940 item_id: 649 rating: 3.5408271516197627
# user_id: 940 item_id: 650 rating: 4.243602149100084
# user_id: 940 item_id: 651 rating: 4.052019539815528
# user_id: 940 item_id: 652 rating: 4.175681549711722
# user_id: 940 item_id: 653 rating: 4.310509996931135
# user_id: 940 item_id: 654 rating: 3.9574597403849205
# user_id: 940 item_id: 655 rating: 4.490665721678565
# user_id: 940 item_id: 656 rating: 4.279936877003094
# user_id: 940 item_id: 657 rating: 3.871023132936949
# user_id: 940 item_id: 658 rating: 4.0954902293330715
# user_id: 940 item_id: 659 rating: 3.8613190066935728
# user_id: 940 item_id: 660 rating: 4.324562367788223
# user_id: 940 item_id: 661 rating: 3.8458548570472315
# user_id: 940 item_id: 662 rating: 3.9623752322793075
# user_id: 940 item_id: 663 rating: 3.652647007716705
# user_id: 940 item_id: 664 rating: 3.6041306149435406
# user_id: 940 item_id: 665 rating: 2.8333334791642644
# user_id: 940 item_id: 666 rating: 2.8333335194784035
# user_id: 940 item_id: 667 rating: 2.833333374880027
# user_id: 940 item_id: 668 rating: 2.914373840696613
# user_id: 940 item_id: 669 rating: 3.666383220133155
# user_id: 940 item_id: 670 rating: 4.433612663542558
# user_id: 940 item_id: 671 rating: 3.5608646204640038
# user_id: 940 item_id: 672 rating: 3.8646711091867205
# user_id: 940 item_id: 673 rating: 3.630945486110815
# user_id: 940 item_id: 674 rating: 4.118154964710963
# user_id: 940 item_id: 675 rating: 3.64599986285239
# user_id: 940 item_id: 676 rating: 3.8333333333333335
# user_id: 940 item_id: 677 rating: 3.4129164032091324
# user_id: 940 item_id: 678 rating: 3.6676951177027908
# user_id: 940 item_id: 679 rating: 2.8953866321936794
# user_id: 940 item_id: 680 rating: 3.122142929613978
# user_id: 940 item_id: 681 rating: 3.3965471785143655
# user_id: 940 item_id: 682 rating: 3.0093117610395437
# user_id: 940 item_id: 683 rating: 3.8882068793113183
# user_id: 940 item_id: 684 rating: 3.6888229187397528
# user_id: 940 item_id: 685 rating: 4.043448169028057
# user_id: 940 item_id: 686 rating: 3.0995395589642283
# user_id: 940 item_id: 687 rating: 2.7649387710984588
# user_id: 940 item_id: 688 rating: 3.5546246296920523
# user_id: 940 item_id: 689 rating: 3.672818889764748
# user_id: 940 item_id: 690 rating: 3.8333333333333335
# user_id: 940 item_id: 691 rating: 3.827358534861261
# user_id: 940 item_id: 692 rating: 3.7874238193622665
# user_id: 940 item_id: 693 rating: 4.048857235919709
# user_id: 940 item_id: 694 rating: 3.360043454416595
# user_id: 940 item_id: 695 rating: 3.5840197200769266
# user_id: 940 item_id: 696 rating: 3.458975034714736
# user_id: 940 item_id: 697 rating: 3.8683245249494047
# user_id: 940 item_id: 698 rating: 3.949423599323191
# user_id: 940 item_id: 699 rating: 4.004460364705754
# user_id: 940 item_id: 700 rating: 3.640901865061461
# user_id: 940 item_id: 701 rating: 3.6666794944837044
# user_id: 940 item_id: 702 rating: 3.5984702630189727
# user_id: 940 item_id: 703 rating: 3.814902445204821
# user_id: 940 item_id: 704 rating: 4.319790331606252
# user_id: 940 item_id: 705 rating: 3.8333333333333335
# user_id: 940 item_id: 706 rating: 4.136183111783045
# user_id: 940 item_id: 707 rating: 3.815539166306981
# user_id: 940 item_id: 708 rating: 4.231538146556318
# user_id: 940 item_id: 709 rating: 3.801150862054756
# user_id: 940 item_id: 710 rating: 3.8333333333333335
# user_id: 940 item_id: 711 rating: 3.772445020993088
# user_id: 940 item_id: 712 rating: 4.016040494688673
# user_id: 940 item_id: 713 rating: 3.8333333333333335
# user_id: 940 item_id: 714 rating: 3.8021859060690284
# user_id: 940 item_id: 715 rating: 3.745381061758965
# user_id: 940 item_id: 716 rating: 3.1356162884555285
# user_id: 940 item_id: 717 rating: 4.000528838088641
# user_id: 940 item_id: 718 rating: 4.009090273310064
# user_id: 940 item_id: 719 rating: 3.602954157604785
# user_id: 940 item_id: 720 rating: 3.9314228488869505
# user_id: 940 item_id: 721 rating: 3.3493974809379625
# user_id: 940 item_id: 722 rating: 4.08203982272131
# user_id: 940 item_id: 723 rating: 3.8116133613873613
# user_id: 940 item_id: 724 rating: 3.3593741833429682
# user_id: 940 item_id: 725 rating: 3.2771375350612972
# user_id: 940 item_id: 726 rating: 4.038064679366715
# user_id: 940 item_id: 727 rating: 3.447382628222189
# user_id: 940 item_id: 728 rating: 3.6052964727922387
# user_id: 940 item_id: 729 rating: 3.950176211562568
# user_id: 940 item_id: 730 rating: 3.435297027946961
# user_id: 940 item_id: 731 rating: 3.9470293092114566
# user_id: 940 item_id: 732 rating: 3.7088822091577605
# user_id: 940 item_id: 733 rating: 3.2612582234953598
# user_id: 940 item_id: 734 rating: 4.01930658303708
# user_id: 940 item_id: 735 rating: 4.049876341052786
# user_id: 940 item_id: 736 rating: 3.354435985125695
# user_id: 940 item_id: 737 rating: 3.8904172592435127
# user_id: 940 item_id: 738 rating: 3.452242818750503
# user_id: 940 item_id: 739 rating: 3.8147719476082624
# user_id: 940 item_id: 740 rating: 3.8065660512023127
# user_id: 940 item_id: 741 rating: 3.9650417406774507
# user_id: 940 item_id: 742 rating: 2.833273238126056
# user_id: 940 item_id: 743 rating: 4.021832740839172
# user_id: 940 item_id: 744 rating: 3.9753497898401893
# user_id: 940 item_id: 745 rating: 4.035891797714651
# user_id: 940 item_id: 746 rating: 3.8217098763760453
# user_id: 940 item_id: 747 rating: 3.5284660021260708
# user_id: 940 item_id: 748 rating: 3.4243994678650034
# user_id: 940 item_id: 749 rating: 4.032933920791027
# user_id: 940 item_id: 750 rating: 3.57727922867333
# user_id: 940 item_id: 751 rating: 3.86872331789704
# user_id: 940 item_id: 752 rating: 3.4610555268825562
# user_id: 940 item_id: 753 rating: 3.815943480761244
# user_id: 940 item_id: 754 rating: 3.8187404054586986
# user_id: 940 item_id: 755 rating: 3.4844755340332574
# user_id: 940 item_id: 756 rating: 3.8333333333333335
# user_id: 940 item_id: 757 rating: 2.837008385591547
# user_id: 940 item_id: 758 rating: 3.2210600623779198
# user_id: 940 item_id: 759 rating: 3.1734161137104517
# user_id: 940 item_id: 760 rating: 3.522679788564849
# user_id: 940 item_id: 761 rating: 3.826480001610233
# user_id: 940 item_id: 762 rating: 3.7979516335934687
# user_id: 940 item_id: 763 rating: 3.54863005812628
# user_id: 940 item_id: 764 rating: 3.742192083908055
# user_id: 940 item_id: 765 rating: 3.8333333333333335
# user_id: 940 item_id: 766 rating: 3.2068719912247277
# user_id: 940 item_id: 767 rating: 3.753250782387908
# user_id: 940 item_id: 768 rating: 2.730434604579678
# user_id: 940 item_id: 769 rating: 3.845143151069916
# user_id: 940 item_id: 770 rating: 3.425813716884259
# user_id: 940 item_id: 771 rating: 3.6834377053097183
# user_id: 940 item_id: 772 rating: 3.8333333333333335
# user_id: 940 item_id: 773 rating: 3.8129572963721317
# user_id: 940 item_id: 774 rating: 3.667894006139535
# user_id: 940 item_id: 775 rating: 3.8333333333333335
# user_id: 940 item_id: 776 rating: 1.8333337056234735
# user_id: 940 item_id: 777 rating: 3.7854857688305157
# user_id: 940 item_id: 778 rating: 3.433257018200362
# user_id: 940 item_id: 779 rating: 3.5630743584299296
# user_id: 940 item_id: 780 rating: 3.7658113023293076
# user_id: 940 item_id: 781 rating: 3.205119248394841
# user_id: 940 item_id: 782 rating: 3.0661694517976517
# user_id: 940 item_id: 783 rating: 3.8333333333333335
# user_id: 940 item_id: 784 rating: 3.7432322010170758
# user_id: 940 item_id: 785 rating: 3.9906545476088766
# user_id: 940 item_id: 786 rating: 3.3162123832532404
# user_id: 940 item_id: 787 rating: 3.8333333333333335
# user_id: 940 item_id: 788 rating: 3.994971272357746
# user_id: 940 item_id: 789 rating: 3.502667003277858
# user_id: 940 item_id: 790 rating: 3.411212081260754
# user_id: 940 item_id: 791 rating: 3.7401108558853284
# user_id: 940 item_id: 792 rating: 4.681659096586694
# user_id: 940 item_id: 793 rating: 3.829200636617401
# user_id: 940 item_id: 794 rating: 3.852955901003306
# user_id: 940 item_id: 795 rating: 3.84976262299937
# user_id: 940 item_id: 796 rating: 3.685688753919832
# user_id: 940 item_id: 797 rating: 3.1026547341688357
# user_id: 940 item_id: 798 rating: 3.8333333333333335
# user_id: 940 item_id: 799 rating: 3.4029381839613713
# user_id: 940 item_id: 800 rating: 3.5008797604277007
# user_id: 940 item_id: 801 rating: 3.7777730810148675
# user_id: 940 item_id: 802 rating: 3.168934403443152
# user_id: 940 item_id: 803 rating: 4.15713622479604
# user_id: 940 item_id: 804 rating: 3.90287451631967
# user_id: 940 item_id: 805 rating: 3.7108560491399087
# user_id: 940 item_id: 806 rating: 3.4810914864188667
# user_id: 940 item_id: 807 rating: 3.694396983046605
# user_id: 940 item_id: 808 rating: 3.2065663992146183
# user_id: 940 item_id: 809 rating: 3.479227692561608
# user_id: 940 item_id: 810 rating: 3.732510404909801
# user_id: 940 item_id: 811 rating: 3.8897101353404673
# user_id: 940 item_id: 812 rating: 4.045416914429178
# user_id: 940 item_id: 813 rating: 3.8333333333333335
# user_id: 940 item_id: 814 rating: 3.7536401932394665
# user_id: 940 item_id: 815 rating: 3.082213042591227
# user_id: 940 item_id: 816 rating: 3.9983443561046013
# user_id: 940 item_id: 817 rating: 3.642515564130825
# user_id: 940 item_id: 818 rating: 3.493741024603912
# user_id: 940 item_id: 819 rating: 3.5164903410440016
# user_id: 940 item_id: 820 rating: 3.0811654335097276
# user_id: 940 item_id: 821 rating: 3.8333333333333335
# user_id: 940 item_id: 822 rating: 3.3182179439851636
# user_id: 940 item_id: 823 rating: 3.545455542076628
# user_id: 940 item_id: 824 rating: 3.3780678617230118
# user_id: 940 item_id: 825 rating: 3.002908992827511
# user_id: 940 item_id: 826 rating: 2.9254083306971634
# user_id: 940 item_id: 827 rating: 3.3179680263931504
# user_id: 940 item_id: 828 rating: 3.800413265769674
# user_id: 940 item_id: 829 rating: 3.8333333333333335
# user_id: 940 item_id: 830 rating: 3.1139665370860294
# user_id: 940 item_id: 831 rating: 3.6078995547198884
# user_id: 940 item_id: 832 rating: 3.431866776706475
# user_id: 940 item_id: 833 rating: 2.9853703638766964
# user_id: 940 item_id: 834 rating: 3.6523231631569595
# user_id: 940 item_id: 835 rating: 3.8437295815358037
# user_id: 940 item_id: 836 rating: 4.018167370389419
# user_id: 940 item_id: 837 rating: 3.5769430974893908
# user_id: 940 item_id: 838 rating: 2.8333333819817295
# user_id: 940 item_id: 839 rating: 3.16887859139961
# user_id: 940 item_id: 840 rating: 3.0876983162374114
# user_id: 940 item_id: 841 rating: 3.8333333333333335
# user_id: 940 item_id: 842 rating: 3.552909521125462
# user_id: 940 item_id: 843 rating: 3.9206100510236106
# user_id: 940 item_id: 844 rating: 3.609450442971669
# user_id: 940 item_id: 845 rating: 3.595948104137409
# user_id: 940 item_id: 846 rating: 4.194630097578978
# user_id: 940 item_id: 847 rating: 3.8333333333333335
# user_id: 940 item_id: 848 rating: 3.5775019236791916
# user_id: 940 item_id: 849 rating: 3.969125249727405
# user_id: 940 item_id: 850 rating: 4.13912421061489
# user_id: 940 item_id: 851 rating: 3.8333333333333335
# user_id: 940 item_id: 852 rating: 4.568317771264391
# user_id: 940 item_id: 853 rating: 4.416919427262719
# user_id: 940 item_id: 854 rating: 3.816922309188138
# user_id: 940 item_id: 855 rating: 4.268633445045702
# user_id: 940 item_id: 856 rating: 3.8333333333333335
# user_id: 940 item_id: 857 rating: 2.8333333819817295
# user_id: 940 item_id: 858 rating: 3.892224133893983
# user_id: 940 item_id: 859 rating: 3.144227326875611
# user_id: 940 item_id: 860 rating: 3.8333333333333335
# user_id: 940 item_id: 861 rating: 3.464940377988353
# user_id: 940 item_id: 862 rating: 3.9384449011685447
# user_id: 940 item_id: 863 rating: 3.8980206763813525
# user_id: 940 item_id: 864 rating: 4.012591572305766
# user_id: 940 item_id: 865 rating: 3.728541744289727
# user_id: 940 item_id: 866 rating: 4.119369167704169
# user_id: 940 item_id: 867 rating: 3.431009964704825
# user_id: 940 item_id: 868 rating: 3.298508305696134
# user_id: 940 item_id: 869 rating: 4.361178153644745
# user_id: 940 item_id: 870 rating: 3.1240857845270953
# user_id: 940 item_id: 871 rating: 3.4577489918348827
# user_id: 940 item_id: 872 rating: 3.6464947985323057
# user_id: 940 item_id: 873 rating: 3.6183036533825583
# user_id: 940 item_id: 874 rating: 3.910731135744846
# user_id: 940 item_id: 875 rating: 3.262212735106029
# user_id: 940 item_id: 876 rating: 3.714166908565442
# user_id: 940 item_id: 877 rating: 3.5190540713043124
# user_id: 940 item_id: 878 rating: 3.7277595428168975
# user_id: 940 item_id: 879 rating: 3.7166240699342348
# user_id: 940 item_id: 880 rating: 3.1395920521259897
# user_id: 940 item_id: 881 rating: 3.7657085948085878
# user_id: 940 item_id: 882 rating: 3.87958800970041
# user_id: 940 item_id: 883 rating: 3.2802414616126896
# user_id: 940 item_id: 884 rating: 3.263861368955336
# user_id: 940 item_id: 885 rating: 3.8571079612896186
# user_id: 940 item_id: 886 rating: 3.8194285839997417
# user_id: 940 item_id: 887 rating: 3.789368337130975
# user_id: 940 item_id: 888 rating: 3.8333333333333335
# user_id: 940 item_id: 889 rating: 2.6708501168300836
# user_id: 940 item_id: 890 rating: 3.8333333333333335
# user_id: 940 item_id: 891 rating: 3.238340257950648
# user_id: 940 item_id: 892 rating: 2.588756117722511
# user_id: 940 item_id: 893 rating: 4.160122873457945
# user_id: 940 item_id: 894 rating: 3.609638445303725
# user_id: 940 item_id: 895 rating: 4.029396363320016
# user_id: 940 item_id: 896 rating: 4.8333331566981474
# user_id: 940 item_id: 897 rating: 3.0188425206606615
# user_id: 940 item_id: 898 rating: 3.8333333333333335
# user_id: 940 item_id: 899 rating: 3.7360631835905878
# user_id: 940 item_id: 900 rating: 3.7887551290389223
# user_id: 940 item_id: 901 rating: 3.755216960879339
# user_id: 940 item_id: 902 rating: 3.595556074575405
# user_id: 940 item_id: 903 rating: 4.226294300740014
# user_id: 940 item_id: 904 rating: 3.7519710166093034
# user_id: 940 item_id: 905 rating: 3.4209024565093586
# user_id: 940 item_id: 906 rating: 3.8333333333333335
# user_id: 940 item_id: 907 rating: 3.1501347265190116
# user_id: 940 item_id: 908 rating: 3.8333333333333335
# user_id: 940 item_id: 909 rating: 2.345249795761488
# user_id: 940 item_id: 910 rating: 3.8333333333333335
# user_id: 940 item_id: 911 rating: 3.8333333333333335
# user_id: 940 item_id: 912 rating: 4.833333014899768
# user_id: 940 item_id: 913 rating: 3.1486528375157814
# user_id: 940 item_id: 914 rating: 3.8697218802932323
# user_id: 940 item_id: 915 rating: 3.9259838008044188
# user_id: 940 item_id: 916 rating: 3.8333333333333335
# user_id: 940 item_id: 917 rating: 3.8333333333333335
# user_id: 940 item_id: 918 rating: 4.6263829852821345
# user_id: 940 item_id: 919 rating: 3.8333333333333335
# user_id: 940 item_id: 920 rating: 4.0728956491393635
# user_id: 940 item_id: 921 rating: 3.9765507495726404
# user_id: 940 item_id: 922 rating: 4.487045813417098
# user_id: 940 item_id: 923 rating: 3.2126858335988455
# user_id: 940 item_id: 924 rating: 3.7729707563367816
# user_id: 940 item_id: 925 rating: 3.4880931906834274
# user_id: 940 item_id: 926 rating: 3.7291352561609834
# user_id: 940 item_id: 927 rating: 3.7877701350226025
# user_id: 940 item_id: 928 rating: 3.3803121544669135
# user_id: 940 item_id: 929 rating: 3.3966695655931325
# user_id: 940 item_id: 930 rating: 2.9259781844885953
# user_id: 940 item_id: 931 rating: 3.5930512924157125
# user_id: 940 item_id: 932 rating: 4.32899253717647
# user_id: 940 item_id: 933 rating: 3.409660788865093
# user_id: 940 item_id: 934 rating: 3.8333333333333335
# user_id: 940 item_id: 935 rating: 3.863094021496144
# user_id: 940 item_id: 936 rating: 3.7589740058137338
# user_id: 940 item_id: 937 rating: 3.9200926232852993
# user_id: 940 item_id: 938 rating: 3.8091546027806755
# user_id: 940 item_id: 939 rating: 3.286941227229967
# user_id: 940 item_id: 940 rating: 3.565107682159557
# user_id: 940 item_id: 941 rating: 3.798295053083842
# user_id: 940 item_id: 942 rating: 3.6609608618766765
# user_id: 940 item_id: 943 rating: 3.378478335804125
# user_id: 940 item_id: 944 rating: 3.919311350967159
# user_id: 940 item_id: 945 rating: 3.4720000103103947
# user_id: 940 item_id: 946 rating: 3.447298813881899
# user_id: 940 item_id: 947 rating: 2.72498420980407
# user_id: 940 item_id: 948 rating: 3.992022477843121
# user_id: 940 item_id: 949 rating: 3.319991755082486
# user_id: 940 item_id: 950 rating: 3.052574086860462
# user_id: 940 item_id: 951 rating: 3.6576354494618406
# user_id: 940 item_id: 952 rating: 3.689876324510675
# user_id: 940 item_id: 953 rating: 3.8333333333333335
# user_id: 940 item_id: 954 rating: 3.8663582147923843
# user_id: 940 item_id: 955 rating: 3.8187993386796606
# user_id: 940 item_id: 956 rating: 3.8333333333333335
# user_id: 940 item_id: 957 rating: 3.654110284508024
# user_id: 940 item_id: 958 rating: 3.9180349779583628
# user_id: 940 item_id: 959 rating: 3.3280823321146067
# user_id: 940 item_id: 960 rating: 3.9308093628469276
# ...
# user_id: 942 item_id: 1393 rating: 3.5450291953807795
# user_id: 942 item_id: 1394 rating: 3.392405063291139
# user_id: 942 item_id: 1395 rating: 3.469922630024856
# user_id: 942 item_id: 1396 rating: 3.7975894678613518
# user_id: 942 item_id: 1397 rating: 4.392404782894673
# user_id: 942 item_id: 1398 rating: 3.392405063291139
# user_id: 942 item_id: 1399 rating: 3.4752911915802116
# user_id: 942 item_id: 1400 rating: 3.3260458982817096
# user_id: 942 item_id: 1401 rating: 2.661382639774202
# user_id: 942 item_id: 1402 rating: 4.021231009750371
# user_id: 942 item_id: 1403 rating: 3.4762459650375455
# user_id: 942 item_id: 1404 rating: 3.6045548176279145
# user_id: 942 item_id: 1405 rating: 3.392405063291139
# user_id: 942 item_id: 1406 rating: 2.587887259913457
# user_id: 942 item_id: 1407 rating: 1.9960972375392736
# user_id: 942 item_id: 1408 rating: 3.261478108501071
# user_id: 942 item_id: 1409 rating: 3.6818490116027283
# user_id: 942 item_id: 1410 rating: 2.8039173207748895
# user_id: 942 item_id: 1411 rating: 2.454003024637796
# user_id: 942 item_id: 1412 rating: 2.62161856306977
# user_id: 942 item_id: 1413 rating: 2.3924052012476347
# user_id: 942 item_id: 1414 rating: 2.5375386043714387
# user_id: 942 item_id: 1415 rating: 2.88549636390288
# user_id: 942 item_id: 1416 rating: 3.392405063291139
# user_id: 942 item_id: 1417 rating: 3.6350041180534554
# user_id: 942 item_id: 1418 rating: 2.576637534679364
# user_id: 942 item_id: 1419 rating: 2.71349607731984
# user_id: 942 item_id: 1420 rating: 3.0987583658409177
# user_id: 942 item_id: 1421 rating: 3.761644911099195
# user_id: 942 item_id: 1422 rating: 3.392405063291139
# user_id: 942 item_id: 1423 rating: 3.392405063291139
# user_id: 942 item_id: 1424 rating: 2.9154811932547484
# user_id: 942 item_id: 1425 rating: 3.3784079199263504
# user_id: 942 item_id: 1426 rating: 2.8591427666101605
# user_id: 942 item_id: 1427 rating: 3.7486489683052606
# user_id: 942 item_id: 1428 rating: 3.392405063291139
# user_id: 942 item_id: 1429 rating: 3.392405063291139
# user_id: 942 item_id: 1430 rating: 3.253333142027601
# user_id: 942 item_id: 1431 rating: 3.392405063291139
# user_id: 942 item_id: 1432 rating: 3.392405063291139
# user_id: 942 item_id: 1433 rating: 3.8481050528344856
# user_id: 942 item_id: 1434 rating: 3.338534359847706
# user_id: 942 item_id: 1435 rating: 3.392405063291139
# user_id: 942 item_id: 1436 rating: 2.571161476967862
# user_id: 942 item_id: 1437 rating: 2.8773552163185023
# user_id: 942 item_id: 1438 rating: 3.2519783201144876
# user_id: 942 item_id: 1439 rating: 3.144267795074249
# user_id: 942 item_id: 1440 rating: 3.3377414208036456
# user_id: 942 item_id: 1441 rating: 3.0521640666360206
# user_id: 942 item_id: 1442 rating: 3.095414316431343
# user_id: 942 item_id: 1443 rating: 2.50541039787721
# user_id: 942 item_id: 1444 rating: 3.392405063291139
# user_id: 942 item_id: 1445 rating: 3.4361699164874655
# user_id: 942 item_id: 1446 rating: 3.392405063291139
# user_id: 942 item_id: 1447 rating: 3.0441263019647455
# user_id: 942 item_id: 1448 rating: 3.9073058356566217
# user_id: 942 item_id: 1449 rating: 4.044672168059293
# user_id: 942 item_id: 1450 rating: 3.560149385414699
# user_id: 942 item_id: 1451 rating: 3.392405063291139
# user_id: 942 item_id: 1452 rating: 2.3924055707901974
# user_id: 942 item_id: 1453 rating: 2.9575729570202167
# user_id: 942 item_id: 1454 rating: 2.3924052321601135
# user_id: 942 item_id: 1455 rating: 3.392405063291139
# user_id: 942 item_id: 1456 rating: 3.392405063291139
# user_id: 942 item_id: 1457 rating: 3.392405063291139
# user_id: 942 item_id: 1458 rating: 3.2260747640786684
# user_id: 942 item_id: 1459 rating: 3.392405063291139
# user_id: 942 item_id: 1460 rating: 2.3924055707901974
# user_id: 942 item_id: 1461 rating: 3.0499003301605088
# user_id: 942 item_id: 1462 rating: 4.392404555792081
# user_id: 942 item_id: 1463 rating: 3.392405063291139
# user_id: 942 item_id: 1464 rating: 3.392405063291139
# user_id: 942 item_id: 1465 rating: 3.8394994067841552
# user_id: 942 item_id: 1466 rating: 4.392404990152209
# user_id: 942 item_id: 1467 rating: 3.4673892182456196
# user_id: 942 item_id: 1468 rating: 3.3482335893046424
# user_id: 942 item_id: 1469 rating: 2.5906644368858864
# user_id: 942 item_id: 1470 rating: 2.744302443681155
# user_id: 942 item_id: 1471 rating: 3.392405063291139
# user_id: 942 item_id: 1472 rating: 3.827866729677276
# user_id: 942 item_id: 1473 rating: 3.550031681363764
# user_id: 942 item_id: 1474 rating: 3.498935341889634
# user_id: 942 item_id: 1475 rating: 3.392405063291139
# user_id: 942 item_id: 1476 rating: 3.392405063291139
# user_id: 942 item_id: 1477 rating: 3.0182527734840816
# user_id: 942 item_id: 1478 rating: 3.1536701720185616
# user_id: 942 item_id: 1479 rating: 2.495190936006776
# user_id: 942 item_id: 1480 rating: 2.578090555978879
# user_id: 942 item_id: 1481 rating: 3.392405063291139
# user_id: 942 item_id: 1482 rating: 3.3136606878925816
# user_id: 942 item_id: 1483 rating: 3.392405063291139
# user_id: 942 item_id: 1484 rating: 3.392405063291139
# user_id: 942 item_id: 1485 rating: 1.392405720879109
# user_id: 942 item_id: 1486 rating: 2.9799426305596404
# user_id: 942 item_id: 1487 rating: 3.392405063291139
# user_id: 942 item_id: 1488 rating: 2.389324786502726
# user_id: 942 item_id: 1489 rating: 3.392405063291139
# user_id: 942 item_id: 1490 rating: 4.811674850528234
# user_id: 942 item_id: 1491 rating: 3.392405063291139
# user_id: 942 item_id: 1492 rating: 1.392405720879109
# user_id: 942 item_id: 1493 rating: 1.392405720879109
# user_id: 942 item_id: 1494 rating: 3.392405063291139
# user_id: 942 item_id: 1495 rating: 2.6959868860631033
# user_id: 942 item_id: 1496 rating: 3.392405063291139
# user_id: 942 item_id: 1497 rating: 3.392405063291139
# user_id: 942 item_id: 1498 rating: 3.3310329061913055
# user_id: 942 item_id: 1499 rating: 4.392404855691766
# user_id: 942 item_id: 1500 rating: 2.9436639873035357
# user_id: 942 item_id: 1501 rating: 1.2775138038412908
# user_id: 942 item_id: 1502 rating: 3.0464446621293164
# user_id: 942 item_id: 1503 rating: 3.392405063291139
# user_id: 942 item_id: 1504 rating: 3.392405063291139
# user_id: 942 item_id: 1505 rating: 3.392405063291139
# user_id: 942 item_id: 1506 rating: 3.392405063291139
# user_id: 942 item_id: 1507 rating: 2.7493183042347913
# user_id: 942 item_id: 1508 rating: 2.14404708637302
# user_id: 942 item_id: 1509 rating: 3.392405063291139
# user_id: 942 item_id: 1510 rating: 3.392405063291139
# user_id: 942 item_id: 1511 rating: 2.7781252552394324
# user_id: 942 item_id: 1512 rating: 3.035740345387098
# user_id: 942 item_id: 1513 rating: 3.4170953705206157
# user_id: 942 item_id: 1514 rating: 3.392405063291139
# user_id: 942 item_id: 1515 rating: 3.9590845517891307
# user_id: 942 item_id: 1516 rating: 2.9720554909993298
# user_id: 942 item_id: 1517 rating: 2.8270061529883233
# user_id: 942 item_id: 1518 rating: 3.392405063291139
# user_id: 942 item_id: 1519 rating: 3.392405063291139
# user_id: 942 item_id: 1520 rating: 3.392405063291139
# user_id: 942 item_id: 1521 rating: 3.3016960658065337
# user_id: 942 item_id: 1522 rating: 2.792405178077876
# user_id: 942 item_id: 1523 rating: 3.2235251421659976
# user_id: 942 item_id: 1524 rating: 3.392405063291139
# user_id: 942 item_id: 1525 rating: 3.392405063291139
# user_id: 942 item_id: 1526 rating: 3.392405063291139
# user_id: 942 item_id: 1527 rating: 3.392405063291139
# user_id: 942 item_id: 1528 rating: 3.584747878435648
# user_id: 942 item_id: 1529 rating: 2.5427227452785743
# user_id: 942 item_id: 1530 rating: 3.392405063291139
# user_id: 942 item_id: 1531 rating: 3.5796283262063437
# user_id: 942 item_id: 1532 rating: 3.392405063291139
# user_id: 942 item_id: 1533 rating: 3.025831638006231
# user_id: 942 item_id: 1534 rating: 3.392405063291139
# user_id: 942 item_id: 1535 rating: 2.3924066292388777
# user_id: 942 item_id: 1536 rating: 3.392405063291139
# user_id: 942 item_id: 1537 rating: 3.392405063291139
# user_id: 942 item_id: 1538 rating: 2.494411220551308
# user_id: 942 item_id: 1539 rating: 2.8535284360686504
# user_id: 942 item_id: 1540 rating: 3.392405063291139
# user_id: 942 item_id: 1541 rating: 3.392405063291139
# user_id: 942 item_id: 1542 rating: 3.392405063291139
# user_id: 942 item_id: 1543 rating: 3.392405063291139
# user_id: 942 item_id: 1544 rating: 2.564352659658138
# user_id: 942 item_id: 1545 rating: 3.392405063291139
# user_id: 942 item_id: 1546 rating: 3.392405063291139
# user_id: 942 item_id: 1547 rating: 3.392405063291139
# user_id: 942 item_id: 1548 rating: 3.392405063291139
# user_id: 942 item_id: 1549 rating: 3.557590966788275
# user_id: 942 item_id: 1550 rating: 3.392405063291139
# user_id: 942 item_id: 1551 rating: 2.844863666246985
# user_id: 942 item_id: 1552 rating: 3.6821012178281074
# user_id: 942 item_id: 1553 rating: 3.9426329360831325
# user_id: 942 item_id: 1554 rating: 2.8672515923051947
# user_id: 942 item_id: 1555 rating: 3.392405063291139
# user_id: 942 item_id: 1556 rating: 3.392405063291139
# user_id: 942 item_id: 1557 rating: 3.119463089372235
# user_id: 942 item_id: 1558 rating: 3.392405063291139
# user_id: 942 item_id: 1559 rating: 3.392405063291139
# user_id: 942 item_id: 1560 rating: 3.392405063291139
# user_id: 942 item_id: 1561 rating: 3.392405063291139
# user_id: 942 item_id: 1562 rating: 3.392405063291139
# user_id: 942 item_id: 1563 rating: 3.392405063291139
# user_id: 942 item_id: 1564 rating: 3.392405063291139
# user_id: 942 item_id: 1565 rating: 3.392405063291139
# user_id: 942 item_id: 1566 rating: 3.392405063291139
# user_id: 942 item_id: 1567 rating: 3.392405063291139
# user_id: 942 item_id: 1568 rating: 3.392405063291139
# user_id: 942 item_id: 1569 rating: 3.392405063291139
# user_id: 942 item_id: 1570 rating: 3.392405063291139
# user_id: 942 item_id: 1571 rating: 3.392405063291139
# user_id: 942 item_id: 1572 rating: 3.392405063291139
# user_id: 942 item_id: 1573 rating: 3.392405063291139
# user_id: 942 item_id: 1574 rating: 3.392405063291139
# user_id: 942 item_id: 1575 rating: 3.392405063291139
# user_id: 942 item_id: 1576 rating: 3.392405063291139
# user_id: 942 item_id: 1577 rating: 3.392405063291139
# user_id: 942 item_id: 1578 rating: 3.392405063291139
# user_id: 942 item_id: 1579 rating: 3.392405063291139
# user_id: 942 item_id: 1580 rating: 3.392405063291139
# user_id: 942 item_id: 1581 rating: 3.392405063291139
# user_id: 942 item_id: 1582 rating: 3.392405063291139
# user_id: 942 item_id: 1583 rating: 3.392405063291139
# user_id: 942 item_id: 1584 rating: 4.117290978200648
# user_id: 942 item_id: 1585 rating: 3.392405063291139
# user_id: 942 item_id: 1586 rating: 3.392405063291139
# user_id: 942 item_id: 1587 rating: 3.392405063291139
# user_id: 942 item_id: 1588 rating: 3.916482422140832
# user_id: 942 item_id: 1589 rating: 3.392405063291139
# user_id: 942 item_id: 1590 rating: 3.392405063291139
# user_id: 942 item_id: 1591 rating: 2.871095609468117
# user_id: 942 item_id: 1592 rating: 3.392405063291139
# user_id: 942 item_id: 1593 rating: 3.9198688834262843
# user_id: 942 item_id: 1594 rating: 3.392405063291139
# user_id: 942 item_id: 1595 rating: 3.392405063291139
# user_id: 942 item_id: 1596 rating: 3.797100774355666
# user_id: 942 item_id: 1597 rating: 3.0569800490081387
# user_id: 942 item_id: 1598 rating: 2.3924064560562295
# user_id: 942 item_id: 1599 rating: 3.392405063291139
# user_id: 942 item_id: 1600 rating: 2.3924051985686132
# user_id: 942 item_id: 1601 rating: 3.392405063291139
# user_id: 942 item_id: 1602 rating: 3.392405063291139
# user_id: 942 item_id: 1603 rating: 3.392405063291139
# user_id: 942 item_id: 1604 rating: 3.0720616145364543
# user_id: 942 item_id: 1605 rating: 3.392405063291139
# user_id: 942 item_id: 1606 rating: 3.392405063291139
# user_id: 942 item_id: 1607 rating: 2.4869415206459826
# user_id: 942 item_id: 1608 rating: 2.1603493293143705
# user_id: 942 item_id: 1609 rating: 2.3924052555446695
# user_id: 942 item_id: 1610 rating: 3.392405063291139
# user_id: 942 item_id: 1611 rating: 4.392404863251183
# user_id: 942 item_id: 1612 rating: 3.392405063291139
# user_id: 942 item_id: 1613 rating: 3.392405063291139
# user_id: 942 item_id: 1614 rating: 2.8281804161331894
# user_id: 942 item_id: 1615 rating: 3.392405063291139
# user_id: 942 item_id: 1616 rating: 3.392405063291139
# user_id: 942 item_id: 1617 rating: 1.3924053842618374
# user_id: 942 item_id: 1618 rating: 3.392405063291139
# user_id: 942 item_id: 1619 rating: 2.9566802424812777
# user_id: 942 item_id: 1620 rating: 1.3924056089828372
# user_id: 942 item_id: 1621 rating: 3.392405063291139
# user_id: 942 item_id: 1622 rating: 3.804811667946141
# user_id: 942 item_id: 1623 rating: 3.392405063291139
# user_id: 942 item_id: 1624 rating: 3.392405063291139
# user_id: 942 item_id: 1625 rating: 1.3924056348580225
# user_id: 942 item_id: 1626 rating: 3.392405063291139
# user_id: 942 item_id: 1627 rating: 3.4558899044692977
# user_id: 942 item_id: 1628 rating: 3.743201517855429
# user_id: 942 item_id: 1629 rating: 3.392405063291139
# user_id: 942 item_id: 1630 rating: 4.392404858163048
# user_id: 942 item_id: 1631 rating: 3.392405063291139
# user_id: 942 item_id: 1632 rating: 3.392405063291139
# user_id: 942 item_id: 1633 rating: 3.392405063291139
# user_id: 942 item_id: 1634 rating: 3.392405063291139
# user_id: 942 item_id: 1635 rating: 4.392404858163048
# user_id: 942 item_id: 1636 rating: 3.392405063291139
# user_id: 942 item_id: 1637 rating: 3.392405063291139
# user_id: 942 item_id: 1638 rating: 4.2523370620659335
# user_id: 942 item_id: 1639 rating: 3.392405063291139
# user_id: 942 item_id: 1640 rating: 3.392405063291139
# user_id: 942 item_id: 1641 rating: 4.392404891287032
# user_id: 942 item_id: 1642 rating: 3.7817224361370654
# user_id: 942 item_id: 1643 rating: 2.5730032763532074
# user_id: 942 item_id: 1644 rating: 4.392404858163048
# user_id: 942 item_id: 1645 rating: 3.392405063291139
# user_id: 942 item_id: 1646 rating: 3.392405063291139
# user_id: 942 item_id: 1647 rating: 3.392405063291139
# user_id: 942 item_id: 1648 rating: 3.392405063291139
# user_id: 942 item_id: 1649 rating: 4.392404858163048
# user_id: 942 item_id: 1650 rating: 4.392404858163048
# user_id: 942 item_id: 1651 rating: 1.665998641747757
# user_id: 942 item_id: 1652 rating: 3.392405063291139
# user_id: 942 item_id: 1653 rating: 3.392405063291139
# user_id: 942 item_id: 1654 rating: 2.3924051843466403
# user_id: 942 item_id: 1655 rating: 2.3924053366498033
# user_id: 942 item_id: 1656 rating: 3.392405063291139
# user_id: 942 item_id: 1657 rating: 3.392405063291139
# user_id: 942 item_id: 1658 rating: 3.392405062250305
# user_id: 942 item_id: 1659 rating: 3.3924050625972497
# user_id: 942 item_id: 1660 rating: 1.3924057052324328
# user_id: 942 item_id: 1661 rating: 4.392404132593343
# user_id: 942 item_id: 1662 rating: 3.392405063291139
# user_id: 942 item_id: 1663 rating: 3.439090909479748
# user_id: 942 item_id: 1664 rating: 3.392405063291139
# user_id: 942 item_id: 1665 rating: 3.392405063291139
# user_id: 942 item_id: 1666 rating: 3.392405063291139
# user_id: 942 item_id: 1667 rating: 3.392405063291139
# user_id: 942 item_id: 1668 rating: 3.392405063291139
# user_id: 942 item_id: 1669 rating: 3.392405063291139
# user_id: 942 item_id: 1670 rating: 3.392405063291139
# user_id: 942 item_id: 1671 rating: 3.392405063291139
# user_id: 942 item_id: 1672 rating: 4.392404781688661
# user_id: 942 item_id: 1673 rating: 3.392405063291139
# user_id: 942 item_id: 1674 rating: 3.392405063291139
# user_id: 942 item_id: 1675 rating: 2.392405226511259
# user_id: 942 item_id: 1676 rating: 3.392405063291139
# user_id: 942 item_id: 1677 rating: 3.392405063291139
# user_id: 942 item_id: 1678 rating: 3.392405063291139
# user_id: 942 item_id: 1679 rating: 3.392405063291139
# user_id: 942 item_id: 1680 rating: 3.392405063291139
# user_id: 942 item_id: 1681 rating: 3.392405063291139
#          user_id  item_id  predicted_rating
# 0              0        0          4.048754
# 1              0        1          3.612426
# 2              0        2          3.401359
# 3              0        3          3.717114
# 4              0        4          3.465786
# ...          ...      ...               ...
# 1586087      942     1677          3.392405
# 1586088      942     1678          3.392405
# 1586089      942     1679          3.392405
# 1586090      942     1680          3.392405
# 1586091      942     1681          3.392405
#
# [1586092 rows x 3 columns]

# %%
ratings_pivot = ratings_predict.pivot(index='item_id', columns='user_id', values='predicted_rating')
ratings_pivot
# Out:
# user_id       0         1         2         3         4         5         6    \
# item_id
# 0        4.048754  3.713398  3.166526  4.589606  3.390088  3.740628  4.335887
# 1        3.612426  3.478433  2.762915  3.793576  2.842411  3.288998  3.846055
# 2        3.401359  3.615732  2.702551  3.642919  2.647279  3.308597  3.796036
# 3        3.717114  3.696342  3.022883  4.069061  3.069831  3.707334  4.463244
# 4        3.465786  3.750673  2.836971  4.113240  2.843313  3.331556  3.918864
# ...           ...       ...       ...       ...       ...       ...       ...
# 1677     1.603054  1.750001  4.909090  5.000000  0.909092  1.631841  3.959288
# 1678     3.603053  3.750000  2.909091  4.357143  2.909091  3.631841  3.959288
# 1679     2.603054  2.750001  3.909091  5.000000  1.909092  2.631841  3.959288
# 1680     3.603053  3.750000  2.909091  4.357143  2.909091  3.631841  3.959288
# 1681     3.603053  3.750000  2.909091  4.357143  2.909091  3.631841  3.959288
#
# user_id       7         8         9    ...       933       934       935  \
# item_id                                ...
# 0        4.063631  3.556423  4.110697  ...  3.432569  4.123193  3.703624
# 1        3.837736  3.999173  4.022395  ...  3.735400  3.936213  3.391353
# 2        3.729247  3.166667  3.787438  ...  3.496386  3.738482  3.475934
# 3        3.927591  3.683975  4.011475  ...  4.187489  3.872257  3.785101
# 4        3.713959  4.408915  4.226266  ...  3.534925  3.939929  3.608942
# ...           ...       ...       ...  ...       ...       ...       ...
# 1677     1.857143  4.166667  2.201150  ...  3.707317  1.965518  1.742424
# 1678     3.857143  4.166667  4.201149  ...  3.707317  3.965517  3.742424
# 1679     2.857143  4.166667  3.201150  ...  3.707317  2.965517  2.742424
# 1680     3.857143  4.166667  4.201149  ...  3.707317  3.965517  3.742424
# 1681     3.857143  4.166667  4.201149  ...  3.707317  3.965517  3.742424
#
# user_id       936       937       938       939       940       941       942
# item_id
# 0        3.302537  3.411483  4.642177  3.575000  4.706250  4.331609  3.487957
# 1        3.014445  3.112762  4.243597  3.370709  3.672772  4.060193  3.587609
# 2        2.844094  2.994189  4.038683  3.426049  3.578102  3.638851  3.026260
# 3        3.089386  3.250595  4.349099  2.919212  3.730435  4.228549  3.479864
# 4        3.146740  3.221646  4.060898  3.348898  3.708581  4.121265  3.164883
# ...           ...       ...       ...       ...       ...       ...       ...
# 1677     5.000000  1.306123  4.307692  1.463919  3.833333  2.304348  3.392405
# 1678     3.233333  3.306122  4.307692  3.463918  3.833333  4.304348  3.392405
# 1679     4.233333  2.306123  4.307692  2.463918  3.833333  3.304348  3.392405
# 1680     3.233333  3.306122  4.307692  3.463918  3.833333  4.304348  3.392405
# 1681     3.233333  3.306122  4.307692  3.463918  3.833333  4.304348  3.392405
#
# [1682 rows x 943 columns]

# %%
ratings_pivot_filled = ratings_pivot.fillna(0)
ratings_pivot_filled
# Out:
# user_id       0         1         2         3         4         5         6    \
# item_id
# 0        4.048754  3.713398  3.166526  4.589606  3.390088  3.740628  4.335887
# 1        3.612426  3.478433  2.762915  3.793576  2.842411  3.288998  3.846055
# 2        3.401359  3.615732  2.702551  3.642919  2.647279  3.308597  3.796036
# 3        3.717114  3.696342  3.022883  4.069061  3.069831  3.707334  4.463244
# 4        3.465786  3.750673  2.836971  4.113240  2.843313  3.331556  3.918864
# ...           ...       ...       ...       ...       ...       ...       ...
# 1677     1.603054  1.750001  4.909090  5.000000  0.909092  1.631841  3.959288
# 1678     3.603053  3.750000  2.909091  4.357143  2.909091  3.631841  3.959288
# 1679     2.603054  2.750001  3.909091  5.000000  1.909092  2.631841  3.959288
# 1680     3.603053  3.750000  2.909091  4.357143  2.909091  3.631841  3.959288
# 1681     3.603053  3.750000  2.909091  4.357143  2.909091  3.631841  3.959288
#
# user_id       7         8         9    ...       933       934       935  \
# item_id                                ...
# 0        4.063631  3.556423  4.110697  ...  3.432569  4.123193  3.703624
# 1        3.837736  3.999173  4.022395  ...  3.735400  3.936213  3.391353
# 2        3.729247  3.166667  3.787438  ...  3.496386  3.738482  3.475934
# 3        3.927591  3.683975  4.011475  ...  4.187489  3.872257  3.785101
# 4        3.713959  4.408915  4.226266  ...  3.534925  3.939929  3.608942
# ...           ...       ...       ...  ...       ...       ...       ...
# 1677     1.857143  4.166667  2.201150  ...  3.707317  1.965518  1.742424
# 1678     3.857143  4.166667  4.201149  ...  3.707317  3.965517  3.742424
# 1679     2.857143  4.166667  3.201150  ...  3.707317  2.965517  2.742424
# 1680     3.857143  4.166667  4.201149  ...  3.707317  3.965517  3.742424
# 1681     3.857143  4.166667  4.201149  ...  3.707317  3.965517  3.742424
#
# user_id       936       937       938       939       940       941       942
# item_id
# 0        3.302537  3.411483  4.642177  3.575000  4.706250  4.331609  3.487957
# 1        3.014445  3.112762  4.243597  3.370709  3.672772  4.060193  3.587609
# 2        2.844094  2.994189  4.038683  3.426049  3.578102  3.638851  3.026260
# 3        3.089386  3.250595  4.349099  2.919212  3.730435  4.228549  3.479864
# 4        3.146740  3.221646  4.060898  3.348898  3.708581  4.121265  3.164883
# ...           ...       ...       ...       ...       ...       ...       ...
# 1677     5.000000  1.306123  4.307692  1.463919  3.833333  2.304348  3.392405
# 1678     3.233333  3.306122  4.307692  3.463918  3.833333  4.304348  3.392405
# 1679     4.233333  2.306123  4.307692  2.463918  3.833333  3.304348  3.392405
# 1680     3.233333  3.306122  4.307692  3.463918  3.833333  4.304348  3.392405
# 1681     3.233333  3.306122  4.307692  3.463918  3.833333  4.304348  3.392405
#
# [1682 rows x 943 columns]

# %%
ratings_pivot_filled.to_csv('/content/drive/MyDrive/Recommendation-System/ratings_pivot_filled.csv', index=True)

# %%
recommendations = rs.recommend_top_k(942, top_k = 10)
recommendations
# Out:
# [(829, 5),
#  (851, 5),
#  (890, 5),
#  (896, 5),
#  (1308, 5),
#  (1490, 4.811674850528234),
#  (1307, 4.504718145959886),
#  (912, 4.456514951946335),
#  (852, 4.408897802980359),
#  (1466, 4.392404990152209)]

# %%
recommendation_ids = [pair[0] for pair in recommendations]
print(recommendation_ids)
# Out:
# [829, 851, 890, 896, 1308, 1490, 1307, 912, 852, 1466]

# %%
rs.print_recommendation()

# %%
rs = CF(rate_train, k = 30, uuCF = 0)
rs.fit()

n_tests = rate_test.shape[0]
SE = 0 # squared error
for n in range(n_tests):
    pred = rs.pred(rate_test[n, 0], rate_test[n, 1], normalized = 0)
    SE += (pred - rate_test[n, 2])**2

RMSE = np.sqrt(SE/n_tests)
print('Item-item CF, RMSE =', RMSE)
